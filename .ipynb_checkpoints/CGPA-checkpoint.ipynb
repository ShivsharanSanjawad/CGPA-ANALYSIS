# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Record.csv")

# %%
df.head()
# Out:
#   Unnamed: 0  Unnamed: 1           Subject Code                    MA102  \
# 0        NaN         NaN           Subject Name           Mathematics II
# 1    Sr. No.     UID No.                   Name  ESE\rmarks(ou\rt of 100
# 2        NaN         NaN      min passing marks                       33
# 3          1  2023300001          AARYAN MANTRI                       76
# 4          2  2023300002  AGARWAL VEDANT RAKESH                       93
#
#                                                EC102                  AS104  \
# 0                       Basic Electrical Engineering  Engineering Mechanics
# 1  Total\rmarks(out\rof\r100)includ\ring\rTheory\...              Pass/Fail
# 2                                                 34                    NaN
# 3                                                 70                   pass
# 4                                                 91                   pass
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Subject Code', 'MA102', 'EC102', 'AS104',
#        'AS105', 'AS107', 'CE102', 'AEC02', 'LLC02', 'Unnamed: 11',
#        'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
#        'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31',
#        'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35',
#        'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39',
#        'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43',
#        'Unnamed: 44', 'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47',
#        'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51',
#        'Unnamed: 52', 'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55',
#        'Unnamed: 56', 'Unnamed: 57', 'Unnamed: 58'],
#       dtype='object')

# %%
df = df[df.iloc[:, 0].apply(lambda x: str(x).isdigit())]

# %%
df.iloc[1]
# Out:
# Unnamed: 0                          2
# Unnamed: 1                 2023300002
# Subject Code    AGARWAL VEDANT RAKESH
# MA102                              93
# EC102                              91
# AS104                            pass
# AS105                              AA
# AS107                               4
# CE102                              10
# AEC02                              40
# LLC02                              74
# Unnamed: 11                        75
# Unnamed: 12                      pass
# Unnamed: 13                        AB
# Unnamed: 14                         4
# Unnamed: 15                         9
# Unnamed: 16                        36
# Unnamed: 17                        62
# Unnamed: 18                        79
# Unnamed: 19                      pass
# Unnamed: 20                        AB
# Unnamed: 21                         3
# Unnamed: 22                         9
# Unnamed: 23                        27
# Unnamed: 24                       NaN
# ...

# %%
df.drop(df.columns[0],axis=1,inplace=True)
df.columns
# Out:
# Index(['Unnamed: 1', 'Subject Code', 'MA102', 'EC102', 'AS104', 'AS105',
#        'AS107', 'CE102', 'AEC02', 'LLC02', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
#        'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
#        'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36',
#        'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40',
#        'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44',
#        'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48',
#        'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52',
#        'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56',
#        'Unnamed: 57', 'Unnamed: 58'],
#       dtype='object')

# %%
df = df.rename(columns={
    "Unnamed: 1": "UID", 
    "Subject Code": "Name",
    "MA102": "Maths_ESE",
    "EC102": "Maths_Total",
    "AS104": "Maths_Status",
    "AS105": "Maths_Grade",
    "AS107": "Maths_Credit",
    "CE102": "Maths_GPA",
    "AEC02": "Maths_GPC",
    "LLC02": "BEE_ESE",
    "Unnamed: 11": "BEE_Total",
    "Unnamed: 12": "BEE_Status",
    "Unnamed: 13": "BEE_Grade",
    "Unnamed: 14": "BEE_Credit",
    "Unnamed: 15": "BEE_GPA",
    "Unnamed: 16": "BEE_GPC",
    "Unnamed: 17": "EM_ESE",
    "Unnamed: 18": "EM_Total",
    "Unnamed: 19": "EM_Status",
    "Unnamed: 20": "EM_Grade",
    "Unnamed: 21": "EM_Credit",
    "Unnamed: 22": "EM_GPA",
    "Unnamed: 23": "EM_GPC",
    "Unnamed: 24": "EG_ESE",
    "Unnamed: 25": "EG_Total",
    "Unnamed: 26": "EG_Status",
    "Unnamed: 27": "EG_Grade",
    "Unnamed: 28": "EG_Credit",
    "Unnamed: 29": "EG_GPA",
    "Unnamed: 30": "EG_GPC",
    "Unnamed: 31": "SS_Total",  
    "Unnamed: 32": "SS_Status",
    "Unnamed: 33": "SS_Grade",
    "Unnamed: 34": "SS_Credit",
    "Unnamed: 35": "SS_GPA",
    "Unnamed: 36": "SS_GPC",
    "Unnamed: 37": "PSOOP_Total",  
    "Unnamed: 38": "PSOOP_Status",
    "Unnamed: 39": "PSOOP_Grade",
    "Unnamed: 40": "PSOOP_Credit",
    "Unnamed: 41": "PSOOP_GPA",
    "Unnamed: 42": "PSOOP_GPC",
    "Unnamed: 43": "UHV_Total",  
    "Unnamed: 44": "UHV_Status",
    "Unnamed: 45": "UHV_Grade",
    "Unnamed: 46": "UHV_Credit",
    "Unnamed: 47": "UHV_GPA",
    "Unnamed: 48": "UHV_GPC",
    "Unnamed: 49": "LLC_Total",  
    "Unnamed: 50": "LLC_Grade",
    "Unnamed: 51": "LLC_Credit",
    "Unnamed: 52": "LLC_GPA",
    "Unnamed: 53": "LLC_GPC",
    "Unnamed: 54": "Total_Credits",
    "Unnamed: 55": "Total_Credits_Earned",
    "Unnamed: 56": "Total_GPC_Earned",
    "Unnamed: 57": "SGPA",
    "Unnamed: 58": "Result"
})

# %%
def validate_sgpa(x):
    try:
        value = float(x)
        return value if 0 <= value <= 10 else np.nan
    except ValueError:
        return np.nan

# %%
df.to_csv("resultant.csv")
df["SGPA"] = df["SGPA"].apply(validate_sgpa)
df["Total_GPC_Earned"] = pd.to_numeric(df["Total_GPC_Earned"], errors='coerce')
df["Total_Credits_Earned"] = pd.to_numeric(df["Total_Credits_Earned"], errors='coerce')
df.loc[df["Total_Credits_Earned"] == 0, "SGPA"] = 0
df["SGPA"] = df["SGPA"].fillna(df["Total_GPC_Earned"] /190)
df.to_csv("resultant.csv")
df.isnull().sum()
# Out:
# UID                       0
# Name                      0
# Maths_ESE                 0
# Maths_Total               0
# Maths_Status              0
# Maths_Grade               0
# Maths_Credit              0
# Maths_GPA                 0
# Maths_GPC                 0
# BEE_ESE                   0
# BEE_Total                 0
# BEE_Status                0
# BEE_Grade                 0
# BEE_Credit                0
# BEE_GPA                   0
# BEE_GPC                   0
# EM_ESE                  135
# EM_Total                135
# EM_Status               135
# EM_Grade                135
# EM_Credit               135
# EM_GPA                  135
# EM_GPC                  134
# EG_ESE                  133
# EG_Total                133
# EG_Status               133
# EG_Grade                133
# EG_Credit               133
# EG_GPA                  133
# EG_GPC                  133
# SS_Total                  0
# SS_Status                 0
# SS_Grade                  0
# ...

# %%
columns_to_fill = [
    "EM_ESE", "EM_Total", "EM_Status", "EM_Grade", "EM_Credit", 
    "EM_GPA", "EM_GPC", "EG_ESE", "EG_Total", "EG_Status", 
    "EG_Grade", "EG_Credit", "EG_GPA", "EG_GPC"
]

# Fill NaN values in the specified columns with 0
df[columns_to_fill] = df[columns_to_fill].fillna(0)
df.isnull().sum()
# Out:
# UID                      0
# Name                     0
# Maths_ESE                0
# Maths_Total              0
# Maths_Status             0
# Maths_Grade              0
# Maths_Credit             0
# Maths_GPA                0
# Maths_GPC                0
# BEE_ESE                  0
# BEE_Total                0
# BEE_Status               0
# BEE_Grade                0
# BEE_Credit               0
# BEE_GPA                  0
# BEE_GPC                  0
# EM_ESE                   0
# EM_Total                 0
# EM_Status                0
# EM_Grade                 0
# EM_Credit                0
# EM_GPA                   0
# EM_GPC                   0
# EG_ESE                   0
# EG_Total                 0
# EG_Status                0
# EG_Grade                 0
# EG_Credit                0
# EG_GPA                   0
# EG_GPC                   0
# SS_Total                 0
# SS_Status                0
# SS_Grade                 0
# SS_Credit                0
# ...

# %%
#used chatgpt for syntax
total_or_ese_cols = df.filter(like='Total').columns.tolist() + \
                    df.filter(like='ESE').columns.tolist() + \
                    df.filter(like='GPA').columns.tolist() + \
                    df.filter(like='GPC').columns.tolist() +\
                    df.filter(like='Credit').columns.tolist() +\
                    df.filter(like='UID').columns.tolist()
for col in total_or_ese_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')
df = df[df["SGPA"]!=0]
df.to_csv("resultant.csv")

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 263 entries, 3 to 273
# Data columns (total 58 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   UID                   263 non-null    int64
#  1   Name                  263 non-null    object
#  2   Maths_ESE             259 non-null    float64
#  3   Maths_Total           262 non-null    float64
#  4   Maths_Status          263 non-null    object
#  5   Maths_Grade           263 non-null    object
#  6   Maths_Credit          263 non-null    int64
#  7   Maths_GPA             263 non-null    int64
#  8   Maths_GPC             263 non-null    float64
#  9   BEE_ESE               258 non-null    float64
#  10  BEE_Total             261 non-null    float64
#  11  BEE_Status            263 non-null    object
#  12  BEE_Grade             263 non-null    object
#  13  BEE_Credit            263 non-null    int64
#  14  BEE_GPA               263 non-null    int64
# ...

# %%
df[df["Name"].str.contains("KUMAAR")]
# Out:
#             UID          Name  Maths_ESE  Maths_Total Maths_Status  \
# 131  2023300127  DIVYA KUMAAR       85.0         83.0         pass
#
#     Maths_Grade  Maths_Credit  Maths_GPA  Maths_GPC  BEE_ESE  ...  LLC_Total  \
# 131          AB             4          9       36.0     68.5  ...       90.0
#
#     LLC_Grade LLC_Credit  LLC_GPA  LLC_GPC  Total_Credits  \
# 131        AA          1       10       10           19.0
#
#      Total_Credits_Earned  Total_GPC_Earned  SGPA      Result
# 131                  19.0             182.0  9.58  Successful
#
# [1 rows x 58 columns]

# %%
df["BEE_ESE"].isnull().sum()
# Out:
# np.int64(5)

# %%
df[df["BEE_Total"]>80].sort_values(by="BEE_Total")
# Out:
#             UID                          Name  Maths_ESE  Maths_Total  \
# 33   2023300031          CHAVAN ISHAAN SUYASH       93.0         93.0
# 161  2023300157        PALEKAR PARTH JITENDRA       82.0         83.0
# 261  2023300255            ISHANT NILESH VORA       88.0         84.0
# 263  2023300257            WADEKAR SUMIT ANIL       82.0         80.0
# 133  2023300129        LAKADE VAISHNAVI DILIP       94.0         91.0
# 102  2023300099          KADAM SHIVAM SANTOSH       84.0         90.0
# 227  2023300222        SHENOY RISHABH SANTOSH       84.0         88.0
# 146  2023300142           MEHTA REYANSH NITIN       97.0         94.0
# 199  2023300194  SANJAWAD SHIVSHARAN GURUNATH       86.0         92.0
# 253  2023300247            ATHARV DIPAK THITE       99.0         91.0
# 138  2023300134      VEDAANT SHRINIVAS MAHALE       93.0         88.0
# 159  2023300155           PAI MADHUKAR DEEPAK       83.0         84.0
#
# ...

# %%
df.to_csv("FINAL.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 263 entries, 3 to 273
# Data columns (total 58 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   UID                   263 non-null    int64
#  1   Name                  263 non-null    object
#  2   Maths_ESE             259 non-null    float64
#  3   Maths_Total           262 non-null    float64
#  4   Maths_Status          263 non-null    object
#  5   Maths_Grade           263 non-null    object
#  6   Maths_Credit          263 non-null    int64
#  7   Maths_GPA             263 non-null    int64
#  8   Maths_GPC             263 non-null    float64
#  9   BEE_ESE               258 non-null    float64
#  10  BEE_Total             261 non-null    float64
#  11  BEE_Status            263 non-null    object
#  12  BEE_Grade             263 non-null    object
#  13  BEE_Credit            263 non-null    int64
#  14  BEE_GPA               263 non-null    int64
# ...

# %%
plt.scatter(df["EM_Total"]+df["EG_Total"],df["SGPA"])

# %%
x = df["SGPA"]>9

# %%
df.loc[x]
# Out:
#             UID                         Name  Maths_ESE  Maths_Total  \
# 4    2023300002        AGARWAL VEDANT RAKESH       93.0         91.0
# 10   2023300008            BAGADE ARJUN AJAY       82.0         84.0
# 17   2023300015    BHALEKAR SHAMBHAVI SATISH       72.0         69.0
# 21   2023300019         BHATIA BHAVIK SANJAY       86.0         82.0
# 30   2023300028  CHAND VAISHNAVI DNYANESHWAR       95.0         86.0
# ..          ...                          ...        ...          ...
# 252  2023300246          THAKKER VED VVINEET       88.0         80.0
# 253  2023300247           ATHARV DIPAK THITE       99.0         91.0
# 261  2023300255           ISHANT NILESH VORA       88.0         84.0
# 263  2023300257           WADEKAR SUMIT ANIL       82.0         80.0
# 272  2023300266            JAI PARAMESHWARAN       77.0         82.0
#
#     Maths_Status Maths_Grade  Maths_Credit  Maths_GPA  Maths_GPC  BEE_ESE  \
# ...

# %%
sns.kdeplot(df["SGPA"], fill=True)
plt.title('Kernel Density Estimation of SGPA')
plt.xlabel('SGPA')
plt.ylabel('Density')
plt.xlim(0, 10)
# Out:
# (0.0, 10.0)

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df["SGPA"], bins=10, kde=False)
plt.title('Histogram of SGPA')
plt.xlabel('SGPA')
plt.ylabel('Frequency')
plt.xlim(0, 10)
plt.show()
print(len(df[df["SGPA"]<5]))
# Out:
# 61

# %%
df[(df["Maths_ESE"]>70) & (df["SGPA"]<7)]
# Out:
#             UID                     Name  Maths_ESE  Maths_Total Maths_Status  \
# 29   2023300027    BUDHEWAR SOHAM BALAJI       84.0         75.0         pass
# 52   2023300050    DMONTE VALENCIA PETER       94.0         93.0         pass
# 90   2023300087        DAKSH HITESH JAIN       89.0         90.0         pass
# 142  2023300138    MATHUKIA NAMAN ALPESH       85.0         80.0         pass
# 167  2023300163  PASALKAR SHAURYA SURESH       78.0         84.0         pass
# 255  2023300249       VAIDYA MUKUL VIJAY       80.0         79.0         pass
#
#     Maths_Grade  Maths_Credit  Maths_GPA  Maths_GPC  BEE_ESE  ...  LLC_Total  \
# 29           BB             4          8       32.0     50.0  ...       44.0
# 52           AA             4         10       40.0     57.0  ...        NaN
# 90           AA             4         10       40.0     63.5  ...        NaN
# 142          AB             4          9       36.0     21.0  ...       72.0
# ...

# %%
import pandas as pd
from pandas_profiling import ProfileReport
from pydantic_settings import BaseSettings

# Define your settings using Pydantic Settings
class Settings(BaseSettings):
    input_file: str = "FINAL.csv"  # Default value for the input file
    output_file: str = "CGPAreport.html"  # Default value for the output file

    class Config:
        env_file = ".env"  # Optional: Load environment variables from a .env file

# Initialize settings
settings = Settings()


# Create the profile report
profile = ProfileReport(df, title="Pandas Profiling Report", explorative=True)

# Save the report to an HTML file
profile.to_file(settings.output_file)  # Use output file from settings

print(f"Profile report generated successfully: {settings.output_file}")
# Out:
# C:\Users\shivs\AppData\Local\Temp\ipykernel_24060\1223026489.py:2: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport
# ...
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# ) missing from font(s) Arial.Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ydata_profiling\visualisation\utils.py:73: UserWarning: Glyph 13 (
#   plt.savefig(
# ) missing from font(s) Arial.Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ydata_profiling\visualisation\utils.py:73: UserWarning: Glyph 13 (
#   plt.savefig(
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Profile report generated successfully: CGPAreport.html
